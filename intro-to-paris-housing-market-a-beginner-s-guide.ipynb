# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
paris_data=pd.read_csv("C:\\Users\\hirdayesh\\Downloads\\train.csv (1)\\train.csv")

# %%
paris_data
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0          0         34291             24        1        0      47     35693
# 1          1         95145             60        0        1      60     34773
# 2          2         92661             45        1        1      62     45457
# 3          3         97184             99        0        0      59     15113
# 4          4         61752            100        0        0      57     64245
# ...      ...           ...            ...      ...      ...     ...       ...
# 22725  22725         55825             84        1        0      70     12031
# 22726  22726         65870             88        1        0      49     23197
# 22727  22727         93192             42        1        0      39      8539
# 22728  22728         65797             86        1        0      89     23197
# 22729  22729         82244             18        1        0      38     86728
#
# ...

# %% [markdown]
# # Data Analysis

# %%
paris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22730 entries, 0 to 22729
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 22730 non-null  int64
#  1   squareMeters       22730 non-null  int64
#  2   numberOfRooms      22730 non-null  int64
#  3   hasYard            22730 non-null  int64
#  4   hasPool            22730 non-null  int64
#  5   floors             22730 non-null  int64
#  6   cityCode           22730 non-null  int64
#  7   cityPartRange      22730 non-null  int64
#  8   numPrevOwners      22730 non-null  int64
#  9   made               22730 non-null  int64
#  10  isNewBuilt         22730 non-null  int64
#  11  hasStormProtector  22730 non-null  int64
#  12  basement           22730 non-null  int64
#  13  attic              22730 non-null  int64
#  14  garage             22730 non-null  int64
#  15  hasStorageRoom     22730 non-null  int64
# ...

# %%
paris_data.isnull().sum()
# Out:
# id                   0
# squareMeters         0
# numberOfRooms        0
# hasYard              0
# hasPool              0
# floors               0
# cityCode             0
# cityPartRange        0
# numPrevOwners        0
# made                 0
# isNewBuilt           0
# hasStormProtector    0
# basement             0
# attic                0
# garage               0
# hasStorageRoom       0
# hasGuestRoom         0
# price                0
# dtype: int64

# %%
paris_data.describe()
# Out:
#                  id  squareMeters  numberOfRooms       hasYard       hasPool  \
# count  22730.000000  2.273000e+04   22730.000000  22730.000000  22730.000000
# mean   11364.500000  4.658622e+04      48.241091      0.475891      0.452750
# std     6561.730145  4.952124e+04      28.226428      0.499429      0.497773
# min        0.000000  8.900000e+01       1.000000      0.000000      0.000000
# 25%     5682.250000  2.039275e+04      25.000000      0.000000      0.000000
# 50%    11364.500000  4.448400e+04      47.000000      0.000000      0.000000
# 75%    17046.750000  7.154700e+04      75.000000      1.000000      1.000000
# max    22729.000000  6.071330e+06     100.000000      1.000000      1.000000
#
#              floors       cityCode  cityPartRange  numPrevOwners  \
# count  22730.000000   22730.000000   22730.000000   22730.000000
# mean      47.305983   50013.795996       5.585042       5.620766
# std       47.777207   30006.637729       2.739533       2.713026
# ...

# %%
sns.histplot(data = paris_data,x = "price")
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
#sns.pairplot(paris_data)

# %%
paris_data.columns
# Out:
# Index(['id', 'squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors',
#        'cityCode', 'cityPartRange', 'numPrevOwners', 'made', 'isNewBuilt',
#        'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom',
#        'hasGuestRoom', 'price'],
#       dtype='object')

# %%
sns.histplot(y=paris_data["numberOfRooms"])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='numberOfRooms'>

# %%
paris_data[paris_data["numberOfRooms"]==100]
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 4          4         61752            100        0        0      57     64245
# 282      282         74689            100        0        0      38     23878
# 366      366         78304            100        1        0      78      7804
# 380      380         91440            100        0        0      50     26294
# 543      543         51036            100        0        0      10     46536
# ...      ...           ...            ...      ...      ...     ...       ...
# 21721  21721         82819            100        1        0      12     78868
# 22102  22102         91440            100        0        0      74     97423
# 22175  22175         56147            100        0        0     100     74206
# 22205  22205         72871            100        0        1      41     94085
# 22589  22589         35985            100        0        1      51     46266
#
# ...

# %%
paris_data.floors.sort_values(ascending=False).head(15)
sns.countplot(paris_data.floors.sort_values(ascending=False).head(500))
# Out:
# <AxesSubplot:xlabel='floors', ylabel='count'>

# %%
cleanedData=paris_data[paris_data["floors"]<=44]

# %%
cleanedData
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 5          5         30300             36        0        0      35     19069
# 6          6         19341             95        1        0      37     23939
# 7          7         58110              3        1        0       1     67658
# 8          8         20537             84        0        1      44      9560
# 12        12         75124             49        0        0      25     32634
# ...      ...           ...            ...      ...      ...     ...       ...
# 22719  22719          7038             54        0        1      24     98533
# 22720  22720         60886             17        0        0       5     28735
# 22722  22722         35498             32        1        0      41     18325
# 22727  22727         93192             42        1        0      39      8539
# 22729  22729         82244             18        1        0      38     86728
#
# ...

# %%
paris_data.basement.sort_values(ascending=False).head(20)
# Out:
# 15068    91992
# 18926    91978
# 2107     84333
# 3995     81851
# 12829    10000
# 816      10000
# 336      10000
# 8824     10000
# 352      10000
# 971      10000
# 6545     10000
# 18640    10000
# 19194    10000
# 18005    10000
# 1433     10000
# 19389    10000
# 18396    10000
# 4362     10000
# 21159    10000
# 11681    10000
# Name: basement, dtype: int64

# %%
paris_data.attic.sort_values(ascending=False).head(20)
# Out:
# 13633    96381
# 17168    71965
# 12858    71024
# 4909     71001
# 3828     71001
# 19994    30000
# 13642    30000
# 9115     10000
# 2014     10000
# 5991     10000
# 9864     10000
# 833      10000
# 8956     10000
# 13347    10000
# 14162    10000
# 3436      9999
# 16160     9999
# 22116     9999
# 14572     9999
# 13899     9999
# Name: attic, dtype: int64

# %%
paris_data[paris_data.attic == 10000]
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 833      833         96803             80        1        0      78      5352
# 2014    2014         10601             84        1        1      36     98223
# 5991    5991          2804             89        0        0      21      3817
# 8956    8956         28347             95        0        0      41     31263
# 9115    9115         12920              6        1        1      55     65232
# 9864    9864         21149              9        1        0      85     49280
# 13347  13347         44967             69        1        0      80     34228
# 14162  14162         22216             59        0        1      30     50297
#
#        cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 833                7              4  1999           1                  1
# 2014               1             10  2000           0                  1
# ...

# %%
cleanedData  = cleanedData[cleanedData["attic"]<cleanedData["squareMeters"]]

# %%
sns.countplot(paris_data.basement.sort_values(ascending=False).head(20))
# Out:
# <AxesSubplot:xlabel='basement', ylabel='count'>

# %%
paris_data.garage.value_counts(ascending=False)
# Out:
# 377    222
# 414    154
# 404    127
# 976    124
# 308    120
#       ...
# 508      1
# 503      1
# 231      1
# 820      1
# 373      1
# Name: garage, Length: 896, dtype: int64

# %%
cleanedData  = cleanedData[cleanedData["basement"]<cleanedData["squareMeters"]]

# %%
cleanedData
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 5          5         30300             36        0        0      35     19069
# 6          6         19341             95        1        0      37     23939
# 7          7         58110              3        1        0       1     67658
# 8          8         20537             84        0        1      44      9560
# 12        12         75124             49        0        0      25     32634
# ...      ...           ...            ...      ...      ...     ...       ...
# 22718  22718         46336             78        0        1       5     43522
# 22720  22720         60886             17        0        0       5     28735
# 22722  22722         35498             32        1        0      41     18325
# 22727  22727         93192             42        1        0      39      8539
# 22729  22729         82244             18        1        0      38     86728
#
# ...

# %% [markdown]
# To accurately analyze the Paris housing market, we filtered the data and removed properties built prior to 1407, as the oldest Parisian property was constructed in 1407. This allows us to focus on more relevant and recent data.

# %%
cleanedData[(cleanedData["made"]<=2023) & (cleanedData["made"]>=1400 )]
# Out:
#           id  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 5          5         30300             36        0        0      35     19069
# 6          6         19341             95        1        0      37     23939
# 7          7         58110              3        1        0       1     67658
# 8          8         20537             84        0        1      44      9560
# 12        12         75124             49        0        0      25     32634
# ...      ...           ...            ...      ...      ...     ...       ...
# 22718  22718         46336             78        0        1       5     43522
# 22720  22720         60886             17        0        0       5     28735
# 22722  22722         35498             32        1        0      41     18325
# 22727  22727         93192             42        1        0      39      8539
# 22729  22729         82244             18        1        0      38     86728
#
# ...

# %%
#sns.pairplot(cleanedData)

# %%
x=cleanedData.iloc[:,:-1].values
y=cleanedData.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=4)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor()
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([1010724.8, 2834962.3, 5960180.9, ..., 5289891.3, 2852499.6,
#        3537699.3])

# %%
from sklearn.ensemble import RandomForestRegressor
forest=RandomForestRegressor()
forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_1=forest.predict(x_test)
y_pred_1
# Out:
# array([1006452.993, 2834139.547, 5961427.342, ..., 5291321.894,
#        2850950.381, 3547915.089])

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.995649058914934

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 32770455614.120167

# %%
abe=mean_absolute_error(y_test,y_pred)
print(abe)
# Out:
# 11029.172727272742

# %%
# RandomForest
score_1=r2_score(y_test,y_pred_1)
print(score_1)
# Out:
# 0.9968224860278391

# %%
mse_1=mean_squared_error(y_test,y_pred_1)
print(mse_1)
# Out:
# 23932427158.196796

# %%
abe_1=mean_absolute_error(y_test,y_pred_1)
print(abe_1)
# Out:
# 13061.485382588056

# %%
R2=score-score_1
R2
# Out:
# -0.0011734271129050233

# %%
ABE=abe_1-abe
ABE
# Out:
# 2032.3126553153143

# %%
MSE=mse - mse_1
MSE
# Out:
# 8838028455.92337
